# %%
# USGS metadata cleaning – dates & keys
# -------------------------------------------------------------
# This script is meant to run in a Jupyter notebook. You can
# paste cells one-by-one, or run as a .py script. It:
#   - Loads the CSV (no edits to the original file)
#   - Creates a unique key id_page_number
#   - Builds cleaned coordinates (best-available lat/long)
#   - Parses dates_of_recording into year_start / year_end
#   - Enforces the rule: ignore any year > 1980 and any
#     "present/current year/to date" open-ends
#   - Standardizes water_type into a helper column
#   - Exports a non-destructive cleaned copy + a small
#     manual-review file for messy dates
# -------------------------------------------------------------

# %% Imports
import os
import re
import pandas as pd
from typing import Dict, Any, List, Optional, Tuple
import matplotlib.pyplot as plt
import seaborn as sns

# %% User paths (Windows)
DATA_DIR = r"C:\Users\aeliz\Dropbox\Documents\Jupyter Notebooks\chap2_usgs\data"
INPUT_CSV = os.path.join(DATA_DIR, "cleaned_metadata.csv")
# Safe outputs alongside input (non-destructive)
OUTPUT_CSV = os.path.join(DATA_DIR, "cleaned_metadata_with_years.csv")
REVIEW_CSV = os.path.join(DATA_DIR, "dates_needs_review.csv")
WATER_TYPE_REVIEW_CSV = os.path.join(DATA_DIR, "water_type_needs_review.csv")

# %% Load
# We do not modify the original file. We work in-memory, then save NEW files.
df = pd.read_csv(INPUT_CSV, dtype=str, keep_default_na=False)
print(f"Loaded {len(df):,} rows from {INPUT_CSV}")

# %% Basic hygiene: uniform column names (no changes to originals in file)
# Ensure expected columns exist; if not, raise with a helpful message.
required_cols = [
    'id','page_number','inferred_latitude','inferred_longitude',
    'actual_latitude','actual_longitude','location','townships_ranges_sections',
    'watersource_name','actual_county','inferred_county','dates_of_recording',
    'temporal_resolution','units_of_measurement','water_type','keyterms'
]
missing = [c for c in required_cols if c not in df.columns]
if missing:
    raise ValueError(f"Missing expected column(s): {missing}")

# Strip leading/trailing whitespace in all string cells (non-destructive)
df = df.map(lambda x: x.strip() if isinstance(x, str) else x)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 22
#      20 from typing import Dict, Any, List, Optional, Tuple
#      21 import matplotlib.pyplot as plt
# ---> 22 import seaborn as sns
#      24 # %% User paths (Windows)
#      25 DATA_DIR = r"C:\Users\aeliz\Dropbox\Documents\Jupyter Notebooks\chap2_usgs\data"
#
# ModuleNotFoundError: No module named 'seaborn'

# %%
# load preview dataframe 

def preview(dataframe, n=50, random=False, start=None, end=None):
    """
    Preview a chunk of a DataFrame nicely formatted in Jupyter.
    - n: number of rows
    - random=True for random sample
    - start/end: row slice
    """
    if random:
        return dataframe.sample(n).style
    elif start is not None and end is not None:
        return dataframe.loc[start:end].style
    else:
        return dataframe.head(n).style

preview(df, n=100)            # first 100 rows
preview(df, random=True, n=20) # 20 random rows
preview(df, start=500, end=520) # rows 500–520
# Out:
# <style type="text/css">
# </style>
# <table id="T_20c80">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_20c80_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_20c80_level0_col1" class="col_heading level0 col1" >page_number</th>
#       <th id="T_20c80_level0_col2" class="col_heading level0 col2" >inferred_latitude</th>
#       <th id="T_20c80_level0_col3" class="col_heading level0 col3" >inferred_longitude</th>
#       <th id="T_20c80_level0_col4" class="col_heading level0 col4" >actual_latitude</th>
#       <th id="T_20c80_level0_col5" class="col_heading level0 col5" >actual_longitude</th>
#       <th id="T_20c80_level0_col6" class="col_heading level0 col6" >location</th>
#       <th id="T_20c80_level0_col7" class="col_heading level0 col7" >townships_ranges_sections</th>
#       <th id="T_20c80_level0_col8" class="col_heading level0 col8" >watersource_name</th>
#       <th id="T_20c80_level0_col9" class="col_heading level0 col9" >actual_county</th>
#       <th id="T_20c80_level0_col10" class="col_heading level0 col10" >inferred_county</th>
#       <th id="T_20c80_level0_col11" class="col_heading level0 col11" >dates_of_recording</th>
#       <th id="T_20c80_level0_col12" class="col_heading level0 col12" >temporal_resolution</th>
#       <th id="T_20c80_level0_col13" class="col_heading level0 col13" >units_of_measurement</th>
#       <th id="T_20c80_level0_col14" class="col_heading level0 col14" >water_type</th>
#       <th id="T_20c80_level0_col15" class="col_heading level0 col15" >keyterms</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_20c80_level0_row0" class="row_heading level0 row0" >500</th>
#       <td id="T_20c80_row0_col0" class="data row0 col0" >3146</td>
#       <td id="T_20c80_row0_col1" class="data row0 col1" >259</td>
#       <td id="T_20c80_row0_col2" class="data row0 col2" >32.9466</td>
#       <td id="T_20c80_row0_col3" class="data row0 col3" >-110.8504</td>
#       <td id="T_20c80_row0_col4" class="data row0 col4" ></td>
#       <td id="T_20c80_row0_col5" class="data row0 col5" ></td>
#       <td id="T_20c80_row0_col6" class="data row0 col6" >Near Winkelman, Pinal County</td>
#       <td id="T_20c80_row0_col7" class="data row0 col7" >[]</td>
#       <td id="T_20c80_row0_col8" class="data row0 col8" >SAN PEDRO RIVER NEAR WINKELMAN</td>
#       <td id="T_20c80_row0_col9" class="data row0 col9" >Pinal County, Arizona</td>
#       <td id="T_20c80_row0_col10" class="data row0 col10" ></td>
#       <td id="T_20c80_row0_col11" class="data row0 col11" >10/01/1964-09/30/1965</td>
#       <td id="T_20c80_row0_col12" class="data row0 col12" >Daily</td>
#       <td id="T_20c80_row0_col13" class="data row0 col13" >{'Specific_Conductance': 'micromhos at 25°C'}</td>
#       <td id="T_20c80_row0_col14" class="data row0 col14" >Stream Discharge</td>
#       <td id="T_20c80_row0_col15" class="data row0 col15" >['Specific conductance']</td>
#     </tr>
#     <tr>
#       <th id="T_20c80_level0_row1" class="row_heading level0 row1" >501</th>
#       <td id="T_20c80_row1_col0" class="data row1 col0" >1592</td>
#       <td id="T_20c80_row1_col1" class="data row1 col1" >231</td>
#       <td id="T_20c80_row1_col2" class="data row1 col2" >38.1833</td>
#       <td id="T_20c80_row1_col3" class="data row1 col3" >-120.7167</td>
#       <td id="T_20c80_row1_col4" class="data row1 col4" ></td>
#       <td id="T_20c80_row1_col5" class="data row1 col5" ></td>
#       <td id="T_20c80_row1_col6" class="data row1 col6" >Below Salt Springs Dam, North Fork of Mokelumne River</td>
#       <td id="T_20c80_row1_col7" class="data row1 col7" >['[T. 8 N., R. 16 E., Sec. 33]']</td>
#       <td id="T_20c80_row1_col8" class="data row1 col8" >NORTH FORK OF MOKELUMNE RIVER BELOW SALT SPRINGS DAM</td>
#       <td id="T_20c80_row1_col9" class="data row1 col9" >Calaveras County</td>
#       <td id="T_20c80_row1_col10" class="data row1 col10" ></td>
#       <td id="T_20c80_row1_col11" class="data row1 col11" >10/01/1932-09/30/1933</td>
#       <td id="T_20c80_row1_col12" class="data row1 col12" >Daily</td>
#       <td id="T_20c80_row1_col13" class="data row1 col13" >{'Discharge': 'second-feet', 'Gage Height': 'feet'}</td>
#       <td id="T_20c80_row1_col14" class="data row1 col14" >Stream Discharge</td>
#       <td id="T_20c80_row1_col15" class="data row1 col15" >['Discharge', 'Gage Height', 'Run-off']</td>
#     </tr>
#     <tr>
#       <th id="T_20c80_level0_row2" class="row_heading level0 row2" >502</th>
#       <td id="T_20c80_row2_col0" class="data row2 col0" >614</td>
#       <td id="T_20c80_row2_col1" class="data row2 col1" >235</td>
#       <td id="T_20c80_row2_col2" class="data row2 col2" ></td>
#       <td id="T_20c80_row2_col3" class="data row2 col3" ></td>
#       <td id="T_20c80_row2_col4" class="data row2 col4" >37.676111</td>
#       <td id="T_20c80_row2_col5" class="data row2 col5" >-121.264167</td>
#       <td id="T_20c80_row2_col6" class="data row2 col6" >Water-stage recorder in El Pescadero Grant at Durham Ferry highway bridge, 3 miles downstream from Stanislaus River and 3.4 miles northeast of Vernalis</td>
#       <td id="T_20c80_row2_col7" class="data row2 col7" >[]</td>
#       <td id="T_20c80_row2_col8" class="data row2 col8" >San Joaquin River near Vernalis, Calif.</td>
#       <td id="T_20c80_row2_col9" class="data row2 col9" >San Joaquin County</td>
#       <td id="T_20c80_row2_col10" class="data row2 col10" ></td>
#       <td id="T_20c80_row2_col11" class="data row2 col11" >10/01/1947-09/30/1948</td>
#       <td id="T_20c80_row2_col12" class="data row2 col12" >Daily</td>
#       <td id="T_20c80_row2_col13" class="data row2 col13" >Second-feet</td>
#       <td id="T_20c80_row2_col14" class="data row2 col14" >Stream Discharge</td>
#       <td id="T_20c80_row2_col15" class="data row2 col15" >['Discharge', 'San Joaquin River', 'Vernalis', 'stream flow', 'precipitation runoff']</td>
#     </tr>
#     <tr>
#       <th id="T_20c80_level0_row3" class="row_heading level0 row3" >503</th>
#       <td id="T_20c80_row3_col0" class="data row3 col0" >2513</td>
#       <td id="T_20c80_row3_col1" class="data row3 col1" >26</td>
#       <td id="T_20c80_row3_col2" class="data row3 col2" ></td>
#       <td id="T_20c80_row3_col3" class="data row3 col3" ></td>
#       <td id="T_20c80_row3_col4" class="data row3 col4" >34.0522</td>
#       <td id="T_20c80_row3_col5" class="data row3 col5" >-118.2437</td>
#       <td id="T_20c80_row3_col6" class="data row3 col6" >Los Angeles, California</td>
#       <td id="T_20c80_row3_col7" class="data row3 col7" >[]</td>
#       <td id="T_20c80_row3_col8" class="data row3 col8" >Los Angeles Rainfall</td>
#       <td id="T_20c80_row3_col9" class="data row3 col9" >Los Angeles County</td>
#       <td id="T_20c80_row3_col10" class="data row3 col10" ></td>
#       <td id="T_20c80_row3_col11" class="data row3 col11" >07/01/1877-06/30/1946</td>
#       <td id="T_20c80_row3_col12" class="data row3 col12" >Yearly</td>
#       <td id="T_20c80_row3_col13" class="data row3 col13" >inches</td>
#       <td id="T_20c80_row3_col14" class="data row3 col14" >Precipitation</td>
#       <td id="T_20c80_row3_col15" class="data row3 col15" >['Rainfall', 'Cumulative Departure', '68-year Average']</td>
#     </tr>
#     <tr>
#       <th id="T_20c80_level0_row4" class="row_heading level0 row4" >504</th>
#       <td id="T_20c80_row4_col0" class="data row4 col0" >70038394</td>
#       <td id="T_20c80_row4_col1" class="data row4 col1" >49</td>
#       <td id="T_20c80_row4_col2" class="data row4 col2" >34.6461</td>
#       <td id="T_20c80_row4_col3" class="data row4 col3" >-120.4625</td>
#       <td id="T_20c80_row4_col4" class="data row4 col4" ></td>
#       <td id="T_20c80_row4_col5" class="data row4 col5" ></td>
#       <td id="T_20c80_row4_col6" class="data row4 col6" >Near Lompoc, California</td>
#       <td id="T_20c80_row4_col7" class="data row4 col7" >[]</td>
#       <td id="T_20c80_row4_col8" class="data row4 col8" >Santa Ynez River Basin</td>
#       <td id="T_20c80_row4_col9" class="data row4 col9" >Santa Barbara County</td>
#       <td id="T_20c80_row4_col10" class="data row4 col10" ></td>

# %%
# %% Unique key: id_page_number (keep originals too)
# id may repeat across multiple pages; id+page_number is unique per row

def make_key(row: pd.Series) -> str:
    return f"{row['id']}_{row['page_number']}"

df['id_page_number'] = df.apply(make_key, axis=1)

# %% Coordinates: "best available" lat/long helper while preserving originals
# If actual_* exists and is valid, use it; otherwise fall back to inferred_*

# Convert-friendly helper (does not throw on bad values)
def _to_float_or_none(v: Any) -> Optional[float]:
    try:
        if v == '' or v is None:
            return None
        return float(str(v))
    except Exception:
        return None

actual_lat = df['actual_latitude'].map(_to_float_or_none)
actual_lon = df['actual_longitude'].map(_to_float_or_none)
inf_lat    = df['inferred_latitude'].map(_to_float_or_none)
inf_lon    = df['inferred_longitude'].map(_to_float_or_none)

best_lat = actual_lat.where(actual_lat.notna(), inf_lat)
best_lon = actual_lon.where(actual_lon.notna(), inf_lon)

df['latitude']  = best_lat
df['longitude'] = best_lon

# %%
# %% Water type categorization
categories = {
    'groundwater': 'Groundwater',
    'stream discharge': 'Stream discharge',
    'precipitation': 'Precipitation',
    'spring': 'Springs',
    'reservoir': 'Reservoir',
    'water quality': 'Water quality',
    'irrigation': 'Irrigation',
    'not water related': 'Not water related',
    'other': 'Other'
}

def classify_water_type(raw: str) -> Tuple[Optional[str], Optional[str]]:
    if not raw or pd.isna(raw):
        return None, 'MISSING'
    s = raw.lower().strip()
    for key, label in categories.items():
        if key in s:
            return label, None
    return None, raw

results = df['water_type'].apply(classify_water_type)
df['water_type_clean'] = results.apply(lambda x: x[0])
df['water_type_review'] = results.apply(lambda x: x[1])

# Export water_type_review rows if any
needs_wt_review = df[df['water_type_review'].notna()]
if not needs_wt_review.empty:
    try:
        needs_wt_review.to_csv(WATER_TYPE_REVIEW_CSV, index=False)
        print(f"Exported {len(needs_wt_review):,} rows needing water_type review → {WATER_TYPE_REVIEW_CSV}")
    except Exception as e:
        print(f"Could not save {WATER_TYPE_REVIEW_CSV}: {e}")
# Out:
# Could not save C:\Users\aeliz\Dropbox\Documents\Jupyter Notebooks\chap2_usgs\data\water_type_needs_review.csv: [Errno 13] Permission denied: 'C:\\Users\\aeliz\\Dropbox\\Documents\\Jupyter Notebooks\\chap2_usgs\\data\\water_type_needs_review.csv'

# %%
preview(df, start=500, end=520) # rows 500–520
# Out:
# <style type="text/css">
# </style>
# <table id="T_0068b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0068b_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_0068b_level0_col1" class="col_heading level0 col1" >page_number</th>
#       <th id="T_0068b_level0_col2" class="col_heading level0 col2" >inferred_latitude</th>
#       <th id="T_0068b_level0_col3" class="col_heading level0 col3" >inferred_longitude</th>
#       <th id="T_0068b_level0_col4" class="col_heading level0 col4" >actual_latitude</th>
#       <th id="T_0068b_level0_col5" class="col_heading level0 col5" >actual_longitude</th>
#       <th id="T_0068b_level0_col6" class="col_heading level0 col6" >location</th>
#       <th id="T_0068b_level0_col7" class="col_heading level0 col7" >townships_ranges_sections</th>
#       <th id="T_0068b_level0_col8" class="col_heading level0 col8" >watersource_name</th>
#       <th id="T_0068b_level0_col9" class="col_heading level0 col9" >actual_county</th>
#       <th id="T_0068b_level0_col10" class="col_heading level0 col10" >inferred_county</th>
#       <th id="T_0068b_level0_col11" class="col_heading level0 col11" >dates_of_recording</th>
#       <th id="T_0068b_level0_col12" class="col_heading level0 col12" >temporal_resolution</th>
#       <th id="T_0068b_level0_col13" class="col_heading level0 col13" >units_of_measurement</th>
#       <th id="T_0068b_level0_col14" class="col_heading level0 col14" >water_type</th>
#       <th id="T_0068b_level0_col15" class="col_heading level0 col15" >keyterms</th>
#       <th id="T_0068b_level0_col16" class="col_heading level0 col16" >id_page_number</th>
#       <th id="T_0068b_level0_col17" class="col_heading level0 col17" >latitude</th>
#       <th id="T_0068b_level0_col18" class="col_heading level0 col18" >longitude</th>
#       <th id="T_0068b_level0_col19" class="col_heading level0 col19" >water_type_clean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0068b_level0_row0" class="row_heading level0 row0" >500</th>
#       <td id="T_0068b_row0_col0" class="data row0 col0" >3146</td>
#       <td id="T_0068b_row0_col1" class="data row0 col1" >259</td>
#       <td id="T_0068b_row0_col2" class="data row0 col2" >32.9466</td>
#       <td id="T_0068b_row0_col3" class="data row0 col3" >-110.8504</td>
#       <td id="T_0068b_row0_col4" class="data row0 col4" ></td>
#       <td id="T_0068b_row0_col5" class="data row0 col5" ></td>
#       <td id="T_0068b_row0_col6" class="data row0 col6" >Near Winkelman, Pinal County</td>
#       <td id="T_0068b_row0_col7" class="data row0 col7" >[]</td>
#       <td id="T_0068b_row0_col8" class="data row0 col8" >SAN PEDRO RIVER NEAR WINKELMAN</td>
#       <td id="T_0068b_row0_col9" class="data row0 col9" >Pinal County, Arizona</td>
#       <td id="T_0068b_row0_col10" class="data row0 col10" ></td>
#       <td id="T_0068b_row0_col11" class="data row0 col11" >10/01/1964-09/30/1965</td>
#       <td id="T_0068b_row0_col12" class="data row0 col12" >Daily</td>
#       <td id="T_0068b_row0_col13" class="data row0 col13" >{'Specific_Conductance': 'micromhos at 25°C'}</td>
#       <td id="T_0068b_row0_col14" class="data row0 col14" >Stream Discharge</td>
#       <td id="T_0068b_row0_col15" class="data row0 col15" >['Specific conductance']</td>
#       <td id="T_0068b_row0_col16" class="data row0 col16" >3146_259</td>
#       <td id="T_0068b_row0_col17" class="data row0 col17" >32.946600</td>
#       <td id="T_0068b_row0_col18" class="data row0 col18" >-110.850400</td>
#       <td id="T_0068b_row0_col19" class="data row0 col19" >stream discharge</td>
#     </tr>
#     <tr>
#       <th id="T_0068b_level0_row1" class="row_heading level0 row1" >501</th>
#       <td id="T_0068b_row1_col0" class="data row1 col0" >1592</td>
#       <td id="T_0068b_row1_col1" class="data row1 col1" >231</td>
#       <td id="T_0068b_row1_col2" class="data row1 col2" >38.1833</td>
#       <td id="T_0068b_row1_col3" class="data row1 col3" >-120.7167</td>
#       <td id="T_0068b_row1_col4" class="data row1 col4" ></td>
#       <td id="T_0068b_row1_col5" class="data row1 col5" ></td>
#       <td id="T_0068b_row1_col6" class="data row1 col6" >Below Salt Springs Dam, North Fork of Mokelumne River</td>
#       <td id="T_0068b_row1_col7" class="data row1 col7" >['[T. 8 N., R. 16 E., Sec. 33]']</td>
#       <td id="T_0068b_row1_col8" class="data row1 col8" >NORTH FORK OF MOKELUMNE RIVER BELOW SALT SPRINGS DAM</td>
#       <td id="T_0068b_row1_col9" class="data row1 col9" >Calaveras County</td>
#       <td id="T_0068b_row1_col10" class="data row1 col10" ></td>
#       <td id="T_0068b_row1_col11" class="data row1 col11" >10/01/1932-09/30/1933</td>
#       <td id="T_0068b_row1_col12" class="data row1 col12" >Daily</td>
#       <td id="T_0068b_row1_col13" class="data row1 col13" >{'Discharge': 'second-feet', 'Gage Height': 'feet'}</td>
#       <td id="T_0068b_row1_col14" class="data row1 col14" >Stream Discharge</td>
#       <td id="T_0068b_row1_col15" class="data row1 col15" >['Discharge', 'Gage Height', 'Run-off']</td>
#       <td id="T_0068b_row1_col16" class="data row1 col16" >1592_231</td>
#       <td id="T_0068b_row1_col17" class="data row1 col17" >38.183300</td>
#       <td id="T_0068b_row1_col18" class="data row1 col18" >-120.716700</td>
#       <td id="T_0068b_row1_col19" class="data row1 col19" >stream discharge</td>
#     </tr>
#     <tr>
#       <th id="T_0068b_level0_row2" class="row_heading level0 row2" >502</th>
#       <td id="T_0068b_row2_col0" class="data row2 col0" >614</td>
#       <td id="T_0068b_row2_col1" class="data row2 col1" >235</td>
#       <td id="T_0068b_row2_col2" class="data row2 col2" ></td>
#       <td id="T_0068b_row2_col3" class="data row2 col3" ></td>
#       <td id="T_0068b_row2_col4" class="data row2 col4" >37.676111</td>
#       <td id="T_0068b_row2_col5" class="data row2 col5" >-121.264167</td>
#       <td id="T_0068b_row2_col6" class="data row2 col6" >Water-stage recorder in El Pescadero Grant at Durham Ferry highway bridge, 3 miles downstream from Stanislaus River and 3.4 miles northeast of Vernalis</td>
#       <td id="T_0068b_row2_col7" class="data row2 col7" >[]</td>
#       <td id="T_0068b_row2_col8" class="data row2 col8" >San Joaquin River near Vernalis, Calif.</td>
#       <td id="T_0068b_row2_col9" class="data row2 col9" >San Joaquin County</td>
#       <td id="T_0068b_row2_col10" class="data row2 col10" ></td>
#       <td id="T_0068b_row2_col11" class="data row2 col11" >10/01/1947-09/30/1948</td>
#       <td id="T_0068b_row2_col12" class="data row2 col12" >Daily</td>
#       <td id="T_0068b_row2_col13" class="data row2 col13" >Second-feet</td>
#       <td id="T_0068b_row2_col14" class="data row2 col14" >Stream Discharge</td>
#       <td id="T_0068b_row2_col15" class="data row2 col15" >['Discharge', 'San Joaquin River', 'Vernalis', 'stream flow', 'precipitation runoff']</td>
#       <td id="T_0068b_row2_col16" class="data row2 col16" >614_235</td>
#       <td id="T_0068b_row2_col17" class="data row2 col17" >37.676111</td>
#       <td id="T_0068b_row2_col18" class="data row2 col18" >-121.264167</td>
#       <td id="T_0068b_row2_col19" class="data row2 col19" >stream discharge</td>
#     </tr>
#     <tr>
#       <th id="T_0068b_level0_row3" class="row_heading level0 row3" >503</th>
#       <td id="T_0068b_row3_col0" class="data row3 col0" >2513</td>
#       <td id="T_0068b_row3_col1" class="data row3 col1" >26</td>
#       <td id="T_0068b_row3_col2" class="data row3 col2" ></td>
#       <td id="T_0068b_row3_col3" class="data row3 col3" ></td>
#       <td id="T_0068b_row3_col4" class="data row3 col4" >34.0522</td>
#       <td id="T_0068b_row3_col5" class="data row3 col5" >-118.2437</td>
#       <td id="T_0068b_row3_col6" class="data row3 col6" >Los Angeles, California</td>
#       <td id="T_0068b_row3_col7" class="data row3 col7" >[]</td>
#       <td id="T_0068b_row3_col8" class="data row3 col8" >Los Angeles Rainfall</td>
#       <td id="T_0068b_row3_col9" class="data row3 col9" >Los Angeles County</td>
#       <td id="T_0068b_row3_col10" class="data row3 col10" ></td>
#       <td id="T_0068b_row3_col11" class="data row3 c

# %% [markdown]
# ## Date parsing

# %%
# %% Dates parsing
YEAR_MIN = 1800
YEAR_MAX = 1980

RE_YEAR4   = re.compile(r"\b(18\d{2}|19\d{2}|2000|20\d{2})\b")
RE_MMYYYY  = re.compile(r"\b(0?[1-9]|1[0-2])[\-/](18\d{2}|19\d{2}|20\d{2})\b")
RE_YYYYMMDD= re.compile(r"\b(18\d{2}|19\d{2}|20\d{2})[\-/](0?[1-9]|1[0-2])[\-/]([0-2]?\d|3[01])\b")
RE_TWO_DIGIT_RANGE = re.compile(r"\b(18\d{2}|19\d{2})\s*[-/]\s*(\d{2})\b")

OPEN_TOKENS = (
    'present','to present','current','current year','to current year',
    'to date','t-','t/','tc','open','ongoing'
)

def _normalize_text(s: str) -> str:
    s = s.replace('\u2013','-').replace('\u2014','-')
    s = re.sub(r"[\u2212\u2012\u2015]", "-", s)
    s = s.replace(';', ',')
    s = s.replace('\u00a0', ' ')
    s = re.sub(r"\s+", " ", s)
    return s.strip()

def _expand_two_digit_end(start_year: int, end_two: int) -> int:
    base_century = start_year - (start_year % 100)
    candidate = base_century + end_two
    if end_two < (start_year % 100):
        candidate += 100
    return candidate

def parse_years(raw: Any) -> Dict[str, Any]:
    out = {'year_start': None,'year_end': None,'years_list': None,
           'date_parse_status': None,'date_parse_notes': None,'needs_date_review': False}

    if raw is None:
        out['date_parse_status'] = 'UNPARSED'; out['needs_date_review'] = True; return out

    s = str(raw).strip()
    if s == '' or s.lower() in {'not specified','-','--','n/a','na'}:
        out['date_parse_status'] = 'UNPARSED'; out['needs_date_review'] = True; return out

    norm = _normalize_text(s)
    norm_lower = norm.lower()
    open_ended = any(tok in norm_lower for tok in OPEN_TOKENS)

    years: List[int] = []

    for y in RE_YEAR4.findall(norm):
        try: years.append(int(y))
        except: pass
    for mm, yyyy in RE_MMYYYY.findall(norm):
        try: years.append(int(yyyy))
        except: pass
    for yyyy, mm, dd in RE_YYYYMMDD.findall(norm):
        try: years.append(int(yyyy))
        except: pass
    for start, end2 in RE_TWO_DIGIT_RANGE.findall(norm):
        try:
            s4 = int(start); e2 = int(end2)
            years.append(s4); years.append(_expand_two_digit_end(s4,e2))
        except: pass

    years = [y for y in years if YEAR_MIN <= y <= YEAR_MAX]
    if not years:
        out['date_parse_status'] = 'UNPARSED'; out['date_parse_notes'] = 'no_year_<=1980_found'; out['needs_date_review'] = True; return out

    years = sorted(set(years))
    out['years_list'] = years
    out['year_start'] = min(years)
    if open_ended:
        out['year_end'] = None; out['date_parse_status'] = 'OPEN_ENDED_IGNORED'; out['needs_date_review'] = True
    else:
        out['year_end'] = max(years)
        if len(years) == 1: out['date_parse_status'] = 'SINGLE_YEAR'
        elif len(years) == 2 and out['year_end'] != out['year_start']: out['date_parse_status'] = 'EXACT_RANGE'
        else: out['date_parse_status'] = 'MULTI_YEARS_OR_RANGES'
    return out

# %% Apply parser
df.rename(columns={'dates_of_recording': 'dates_of_recording_raw'}, inplace=True)
parsed = df['dates_of_recording_raw'].apply(parse_years).apply(pd.Series)
# Safe replacement for pd.concat to avoid duplicate columns
for col in parsed.columns:
    df[col] = parsed[col]

# Cast years to Int64
df['year_start'] = df['year_start'].astype('Int64')
df['year_end']   = df['year_end'].astype('Int64')

# %% Quick sanity checks
print("\nSample of parsed years:")
print(df[['dates_of_recording_raw','year_start','year_end','date_parse_status']].head(12))
# Out:
# Sample of parsed years:
#    dates_of_recording_raw  year_start  year_end date_parse_status
# 0         12/1964-09/1966        1964      1966       EXACT_RANGE
# 1   01/01/1912-09/30/1942        1912      1942       EXACT_RANGE
# 2   10/01/1929-09/30/1930        1929      1930       EXACT_RANGE
# 3      03/14/1910-09/1938        1910      1938       EXACT_RANGE
# 4                                <NA>      <NA>          UNPARSED
# 5                                <NA>      <NA>          UNPARSED
# 6                                <NA>      <NA>          UNPARSED
# 7                                <NA>      <NA>          UNPARSED
# 8   10/09/1952-06/16/1950        1950      1952       EXACT_RANGE
# 9   10/01/1968-09/30/1969        1968      1969       EXACT_RANGE
# 10              1880-1880        1880      1880       SINGLE_YEAR
# 11              1884-1898        1884      1898       EXACT_RANGE

# %%
preview(df, start=500, end=520) # rows 500–520
# Out:
# <style type="text/css">
# </style>
# <table id="T_da5c1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da5c1_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_da5c1_level0_col1" class="col_heading level0 col1" >page_number</th>
#       <th id="T_da5c1_level0_col2" class="col_heading level0 col2" >inferred_latitude</th>
#       <th id="T_da5c1_level0_col3" class="col_heading level0 col3" >inferred_longitude</th>
#       <th id="T_da5c1_level0_col4" class="col_heading level0 col4" >actual_latitude</th>
#       <th id="T_da5c1_level0_col5" class="col_heading level0 col5" >actual_longitude</th>
#       <th id="T_da5c1_level0_col6" class="col_heading level0 col6" >location</th>
#       <th id="T_da5c1_level0_col7" class="col_heading level0 col7" >townships_ranges_sections</th>
#       <th id="T_da5c1_level0_col8" class="col_heading level0 col8" >watersource_name</th>
#       <th id="T_da5c1_level0_col9" class="col_heading level0 col9" >actual_county</th>
#       <th id="T_da5c1_level0_col10" class="col_heading level0 col10" >inferred_county</th>
#       <th id="T_da5c1_level0_col11" class="col_heading level0 col11" >dates_of_recording_raw</th>
#       <th id="T_da5c1_level0_col12" class="col_heading level0 col12" >temporal_resolution</th>
#       <th id="T_da5c1_level0_col13" class="col_heading level0 col13" >units_of_measurement</th>
#       <th id="T_da5c1_level0_col14" class="col_heading level0 col14" >water_type</th>
#       <th id="T_da5c1_level0_col15" class="col_heading level0 col15" >keyterms</th>
#       <th id="T_da5c1_level0_col16" class="col_heading level0 col16" >id_page_number</th>
#       <th id="T_da5c1_level0_col17" class="col_heading level0 col17" >latitude</th>
#       <th id="T_da5c1_level0_col18" class="col_heading level0 col18" >longitude</th>
#       <th id="T_da5c1_level0_col19" class="col_heading level0 col19" >water_type_clean</th>
#       <th id="T_da5c1_level0_col20" class="col_heading level0 col20" >year_start</th>
#       <th id="T_da5c1_level0_col21" class="col_heading level0 col21" >year_end</th>
#       <th id="T_da5c1_level0_col22" class="col_heading level0 col22" >years_list</th>
#       <th id="T_da5c1_level0_col23" class="col_heading level0 col23" >date_parse_status</th>
#       <th id="T_da5c1_level0_col24" class="col_heading level0 col24" >date_parse_notes</th>
#       <th id="T_da5c1_level0_col25" class="col_heading level0 col25" >needs_date_review</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da5c1_level0_row0" class="row_heading level0 row0" >500</th>
#       <td id="T_da5c1_row0_col0" class="data row0 col0" >3146</td>
#       <td id="T_da5c1_row0_col1" class="data row0 col1" >259</td>
#       <td id="T_da5c1_row0_col2" class="data row0 col2" >32.9466</td>
#       <td id="T_da5c1_row0_col3" class="data row0 col3" >-110.8504</td>
#       <td id="T_da5c1_row0_col4" class="data row0 col4" ></td>
#       <td id="T_da5c1_row0_col5" class="data row0 col5" ></td>
#       <td id="T_da5c1_row0_col6" class="data row0 col6" >Near Winkelman, Pinal County</td>
#       <td id="T_da5c1_row0_col7" class="data row0 col7" >[]</td>
#       <td id="T_da5c1_row0_col8" class="data row0 col8" >SAN PEDRO RIVER NEAR WINKELMAN</td>
#       <td id="T_da5c1_row0_col9" class="data row0 col9" >Pinal County, Arizona</td>
#       <td id="T_da5c1_row0_col10" class="data row0 col10" ></td>
#       <td id="T_da5c1_row0_col11" class="data row0 col11" >10/01/1964-09/30/1965</td>
#       <td id="T_da5c1_row0_col12" class="data row0 col12" >Daily</td>
#       <td id="T_da5c1_row0_col13" class="data row0 col13" >{'Specific_Conductance': 'micromhos at 25°C'}</td>
#       <td id="T_da5c1_row0_col14" class="data row0 col14" >Stream Discharge</td>
#       <td id="T_da5c1_row0_col15" class="data row0 col15" >['Specific conductance']</td>
#       <td id="T_da5c1_row0_col16" class="data row0 col16" >3146_259</td>
#       <td id="T_da5c1_row0_col17" class="data row0 col17" >32.946600</td>
#       <td id="T_da5c1_row0_col18" class="data row0 col18" >-110.850400</td>
#       <td id="T_da5c1_row0_col19" class="data row0 col19" >stream discharge</td>
#       <td id="T_da5c1_row0_col20" class="data row0 col20" >1964</td>
#       <td id="T_da5c1_row0_col21" class="data row0 col21" >1965</td>
#       <td id="T_da5c1_row0_col22" class="data row0 col22" >[1964, 1965]</td>
#       <td id="T_da5c1_row0_col23" class="data row0 col23" >EXACT_RANGE</td>
#       <td id="T_da5c1_row0_col24" class="data row0 col24" >None</td>
#       <td id="T_da5c1_row0_col25" class="data row0 col25" >False</td>
#     </tr>
#     <tr>
#       <th id="T_da5c1_level0_row1" class="row_heading level0 row1" >501</th>
#       <td id="T_da5c1_row1_col0" class="data row1 col0" >1592</td>
#       <td id="T_da5c1_row1_col1" class="data row1 col1" >231</td>
#       <td id="T_da5c1_row1_col2" class="data row1 col2" >38.1833</td>
#       <td id="T_da5c1_row1_col3" class="data row1 col3" >-120.7167</td>
#       <td id="T_da5c1_row1_col4" class="data row1 col4" ></td>
#       <td id="T_da5c1_row1_col5" class="data row1 col5" ></td>
#       <td id="T_da5c1_row1_col6" class="data row1 col6" >Below Salt Springs Dam, North Fork of Mokelumne River</td>
#       <td id="T_da5c1_row1_col7" class="data row1 col7" >['[T. 8 N., R. 16 E., Sec. 33]']</td>
#       <td id="T_da5c1_row1_col8" class="data row1 col8" >NORTH FORK OF MOKELUMNE RIVER BELOW SALT SPRINGS DAM</td>
#       <td id="T_da5c1_row1_col9" class="data row1 col9" >Calaveras County</td>
#       <td id="T_da5c1_row1_col10" class="data row1 col10" ></td>
#       <td id="T_da5c1_row1_col11" class="data row1 col11" >10/01/1932-09/30/1933</td>
#       <td id="T_da5c1_row1_col12" class="data row1 col12" >Daily</td>
#       <td id="T_da5c1_row1_col13" class="data row1 col13" >{'Discharge': 'second-feet', 'Gage Height': 'feet'}</td>
#       <td id="T_da5c1_row1_col14" class="data row1 col14" >Stream Discharge</td>
#       <td id="T_da5c1_row1_col15" class="data row1 col15" >['Discharge', 'Gage Height', 'Run-off']</td>
#       <td id="T_da5c1_row1_col16" class="data row1 col16" >1592_231</td>
#       <td id="T_da5c1_row1_col17" class="data row1 col17" >38.183300</td>
#       <td id="T_da5c1_row1_col18" class="data row1 col18" >-120.716700</td>
#       <td id="T_da5c1_row1_col19" class="data row1 col19" >stream discharge</td>
#       <td id="T_da5c1_row1_col20" class="data row1 col20" >1932</td>
#       <td id="T_da5c1_row1_col21" class="data row1 col21" >1933</td>
#       <td id="T_da5c1_row1_col22" class="data row1 col22" >[1932, 1933]</td>
#       <td id="T_da5c1_row1_col23" class="data row1 col23" >EXACT_RANGE</td>
#       <td id="T_da5c1_row1_col24" class="data row1 col24" >None</td>
#       <td id="T_da5c1_row1_col25" class="data row1 col25" >False</td>
#     </tr>
#     <tr>
#       <th id="T_da5c1_level0_row2" class="row_heading level0 row2" >502</th>
#       <td id="T_da5c1_row2_col0" class="data row2 col0" >614</td>
#       <td id="T_da5c1_row2_col1" class="data row2 col1" >235</td>
#       <td id="T_da5c1_row2_col2" class="data row2 col2" ></td>
#       <td id="T_da5c1_row2_col3" class="data row2 col3" ></td>
#       <td id="T_da5c1_row2_col4" class="data row2 col4" >37.676111</td>
#       <td id="T_da5c1_row2_col5" class="data row2 col5" >-121.264167</td>
#       <td id="T_da5c1_row2_col6" class="data row2 col6" >Water-stage recorder in El Pescadero Grant at Durham Ferry highway bridge, 3 miles downstream from Stanislaus River and 3.4 miles northeast of Vernalis</td>
#       <td id="T_da5c1_row2_col7" class="data row2 col7" >[]</td>
#       <td id="T_da5c1_row2_col8" class="data row2 col8" >San Joaquin River near Vernalis, Calif.</td>
#       <td id="T_da5c1_row2_col9" class="data row2 col9" >San Joaquin County</td>
#       <td id="T_da5c1_row2_col10" class="data row2 col10" ></td>
#       <td id="T_da5c1_row2_col11" class="data row2 col11" >10/01/1947-09/30/1948</td>
#       <td id="T_da5c1_row2_col12" class="data row2 col12" >Daily</td>
#       <td id="T_da5c1_row2_col13" class="data row2 col13" >Second-feet</td>
#       <td id="T_da5c1_row2_col14" class="data row2 col14" >Strea

# %%
# Check on water_type_clean column for unique values 

# Show all unique values
print(df['water_type_clean'].unique())
# Out:
# ['reservoir' 'stream discharge' 'groundwater'
#  "['groundwater', 'not water related']" "['groundwater', 'irrigation']"
#  'precipitation' 'water quality' 'springs' 'irrigation network station'
#  'irrigation' 'destroyed well' 'domestic well' 'runoff'
#  'not water related' '' 'artesian' 'stock water-table' 'domestic'
#  'discharge' 'storm drain' "['stream discharge', 'precipitation']"
#  'geothermal (not directly related to water)'
#  'glacier (related to stream discharge and precipitation)'
#  'dissolved solids' 'canal discharge'
#  "['stream discharge', 'suspended-sediment discharge']" 'wastewater'
#  'agricultural wastewater' 'storm-water runoff'
#  'groundwater and irrigation' 'observation' 'industrial' 'stock' 'unused'
#  'lake' "['stream discharge', 'water quality']" 'stream' 'domestic water'
#  'canal diversion' 'stream diversion' 'lakes and reservoirs'
#  'estuarine studies' "['stream discharge', 'runoff']"
#  'groundwater, water quality' 'irrigation and domestic use'
#  "['precipitation']" 'seepage' 'canal water'
#  "['stream discharge', 'irrigation']" 'waste water discharge'
#  'bed material' 'conduit outlet' 'bypass' 'artesian well'
#  'stream discharge, water quality' 'estuarine water quality'
#  "['stream discharge', 'stream discharge', 'stream discharge', 'stream discharge']"
#  'effluent' 'miscellaneous' 'canal' 'river' 'diversion' 'domestic; stock'
#  'irrigation; stock.' 'manufacturing' 'domestic; irrigation.'
#  'domestic; irrigation; stock.' 'lake levels' 'imported water'
#  'surface waters' 'canal flow' 'natural lake' 'pumping plant'
#  'ditch discharge' 'pipe line discharge' 'stock well' 'public supply well'
#  "['stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge']"
#  'snow' 'thermoelectric power generation' 'warm springs' 'hot springs'
#  'domestic and stock well' 'unused well' 'lakes' "['concentrate samples']"
#  'river discharge' 'natural discharge' "['groundwater']" 'wells'
#  'surface bed material' "['stream discharge', 'gage height']"
#  'peat bog formation' 'irrigation; stock' 'evaporation' 'estuarine water'
#  'domestic; irrigation' 'laguna'
#  'laguna (natural water channel and overflow basin)' 'lake level'
#  "['stream discharge']" "['stream discharge', 'sediment records']"
#  'sea water' 'lake elevation' "['stream discharge', 'groundwater']"
#  "['reservoir', 'lakes']" 'estuarine' "['reservoir']" 'domestic not used'
#  "['stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge']"
#  'not water related (reference to ocean water analysis)' 'pond' 'culvert'
#  'sump' 'slough' 'pipeline discharge' 'groundwater (perched)' 'spring'
#  'miscellaneous water supplies' 'groundwater and stream discharge'
#  'reservoir and stream discharge' 'stream discharge or groundwater'
#  "['groundwater', 'reservoir']" 'artificial recharge'
#  "['stream discharge', 'stream discharge']" 'recharge' 'oil test hole'
#  'sediment discharge' 'surface water' 'irrigation and domestic'
#  'public-supply' 'periphyton biomass measurements'
#  'groundwater, irrigation'
#  'particle-size distribution of surface bed material'
#  "['groundwater', 'artesian areas']" 'mudflows' 'domestic water supply'
#  'developed water' 'natural flow' 'geothermal' 'power'
#  'domestic and irrigation' 'conduit' 'surface water supply' 'run-off'
#  'hills/foothills' 'valley land' 'hills/creek' 'estuary discharge'
#  'diversion/return flow' "['groundwater', 'stream discharge']"
#  "['stream discharge', 'reservoir']" 'stream discharge, runoff'
#  'stream discharge and reservoir inflow' 'lake discharge'
#  'tidal and nontidal waters' 'stream discharge, irrigation'
#  'irrigation, stream discharge'
#  'lake levels regulated by a concrete dam at the outlet constructed in 1934. regulation is for maintenance of lake level and enhancement of fishery.'
#  'well' 'observation well' 'industrial use' 'chemical analyses'
#  "['stream discharge', 'stream discharge', 'stream discharge', 'stream discharge', 'stream discharge']"
#  "['groundwater', 'water quality']" "['groundwater', 'discharge']"
#  "['irrigation', 'groundwater']" "['discharge', 'irrigation']"
#  "['irrigation']" "['irrigation', 'discharge']" "['discharge']"
#  'annual peaks' 'estuarine (between stream discharge and precipitation)'
#  'water temperature' 'drain'
#  "['groundwater', 'reservoir', 'groundwater', 'groundwater', 'groundwater', 'irrigation', 'not water related', 'springs', 'reservoir', 'spring']"
#  "['reservoir', 'irrigation']" 'domestic and stock'
#  'unused water-table well' 'aqueduct' 'storm drain discharge'
#  "['reservoir', 'stream discharge']" 'chemical quality analysis'
#  'flood plains' 'lake level measurement' 'miscellaneous measurements'
#  "['stream discharge', 'suspended-sediment_discharge']"
#  'wastewater discharges' 'dam' 'groundwater, stream discharge, reservoir'
#  'surface and shallow waters used for domestic and industrial purposes'
#  'brine associated with the oil' 'phytoplankton' 'periphyton' 'lake stage'
#  "['groundwater', 'evaporation from bare land']" 'lake water quality'
#  'stock watering' 'drinking'
#  'particle-size distribution of suspended sediment' 'temperature'
#  'chemical analysis of stream water' 'restaurant supply and domestic'
#  'sediment analysis' 'stock water' 'wastewater discharge'
#  'stream discharge, storm drain discharge'
#  "['stream discharge', 'reservoir', 'precipitation', 'groundwater']"
#  'estuarine waters' 'return flow from stream discharge'
#  'return flow from irrigation' 'standing water'
#  'canal discharge, pipe line discharge' "['groundwater', 'surface water']"
#  'wind' 'gas; wind' 'ocean water' 'saline lake' 'temperature of water'
#  'saline surface water' 'return flow'
#  "['groundwater', 'stream discharge', 'reservoir']" 'underflow'
#  'discharge measurements' 'gage height'
#  "[{'type': 'stream discharge', 'keyterms': ['flood', 'gage washed out']}]"
#  'canal irrigation' 'chemical analysis' 'spring discharge'
#  'well discharge' 'soil water' 'irrigation and groundwater'
#  "['stream discharge', 'stream discharge', 'stream discharge']"
#  'reclaimed water' 'irrigation and stock' 'bath' 'baths' 'turbidity'
#  'stream discharge, precipitation' "['groundwater', 'precipitation']"
#  'aqueduct discharge' 'springs, stream discharge' 'lake water level'
#  "['stream discharge', 'reservoir', 'groundwater']" 'stock and irrigation'
#  'canal, stream discharge' 'sewage effluent'
#  'suspended-sediment discharge' 'drainage basin']

# %%
# %% Quick sanity checks
print("\nSample of parsed years:")
print(df[['dates_of_recording_raw','year_start','year_end','date_parse_status']].head(12))
print("\nUnique water_type_clean values:")
print(df['water_type_clean'].dropna().unique()[:50])
print("\nRows needing water_type_review:")
print(df[df['water_type_review'].notna()][['water_type','water_type_review']].head(20))

# %% Summaries
# Exclude rows where water_type_clean is missing
df_summary = df[df['water_type_clean'].notna()].copy()

# By water type only
summary_by_type = df_summary['water_type_clean'].value_counts().reset_index()
summary_by_type.columns = ['water_type_clean','n_rows']
print("\nSummary by water type:")
print(summary_by_type.head(20))

# By water type × year
summary_by_year = (
    df_summary
    .groupby(['water_type_clean','year_start'])
    .size()
    .reset_index(name='n_rows')
    .sort_values(['water_type_clean','year_start'])
)
print("\nSummary by water type × year:")
print(summary_by_year.head(20))

# By water type × decade
df_summary['decade'] = (df_summary['year_start'] // 10) * 10
summary_by_decade = (
    df_summary
    .groupby(['water_type_clean','decade'])
    .size()
    .reset_index(name='n_rows')
    .sort_values(['water_type_clean','decade'])
)
print("\nSummary by water type × decade:")
print(summary_by_decade.head(20))
# Out:
# Sample of parsed years:
#    dates_of_recording_raw  year_start  year_end date_parse_status
# 0         12/1964-09/1966        1964      1966       EXACT_RANGE
# 1   01/01/1912-09/30/1942        1912      1942       EXACT_RANGE
# 2   10/01/1929-09/30/1930        1929      1930       EXACT_RANGE
# 3      03/14/1910-09/1938        1910      1938       EXACT_RANGE
# 4                                <NA>      <NA>          UNPARSED
# 5                                <NA>      <NA>          UNPARSED
# 6                                <NA>      <NA>          UNPARSED
# 7                                <NA>      <NA>          UNPARSED
# 8   10/09/1952-06/16/1950        1950      1952       EXACT_RANGE
# 9   10/01/1968-09/30/1969        1968      1969       EXACT_RANGE
# 10              1880-1880        1880      1880       SINGLE_YEAR
# 11              1884-1898        1884      1898       EXACT_RANGE
#
# Unique water_type_clean values:
# ['Reservoir' 'Stream discharge' 'Groundwater' 'Precipitation'
#  'Water quality' 'Springs' 'Irrigation' 'Not water related' 'Other']
#
# Rows needing water_type_review:
#                    water_type        water_type_review
# 93             Destroyed Well           Destroyed Well
# 95              Domestic Well            Domestic Well
# 327                    Runoff                   Runoff
# 589                                            MISSING
# 594                  Artesian                 Artesian
# 596                  Artesian                 Artesian
# 597         Stock Water-table        Stock Water-table
# 599                  Domestic                 Domestic
# 768                 Discharge                Discharge
# 840               Storm Drain              Storm Drain
# 844               Storm Drain              Storm Drain
# 853               Storm Drain              Storm Drain
# 1318         Dissolved Solids         Dissolved Solids
# 1429          Canal Discharge          Canal Discharge
# 1683               Wastewater               Wastewater
# 1684  Agricultural wastewater  Agricultural wastewater
# 1685       Storm-water runoff       Storm-water runoff
# 1733          Canal Discharge          Canal Discharge
# 1838          Canal Discharge          Canal Discharge
# 2270              Observation              Observation
#
# Summary by water type:
#     water_type_clean  n_rows
# 0   Stream discharge   44894
# 1        Groundwater   11575
# 2          Reservoir    2546
# 3            Springs    1567
# 4         Irrigation    1408
# 5      Precipitation     483
# 6  Not water related     392
# 7      Water quality     210
# 8              Other       6
#
# Summary by water type × year:
#    water_type_clean  year_start  n_rows
# 0       Groundwater        1856       1
# 1       Groundwater        1863       1
# 2       Groundwater        1868       3
# 3       Groundwater        1869       1
# 4       Groundwater        1870       4
# 5       Groundwater        1873       5
# 6       Groundwater        1874       8
# 7       Groundwater        1875      12
# 8       Groundwater        1876       6
# 9       Groundwater        1877       3
# 10      Groundwater        1878      10
# 11      Groundwater        1879       5
# 12      Groundwater        1880      19
# 13      Groundwater        1881      10
# 14      Groundwater        1882      13
# 15      Groundwater        1883      23
# 16      Groundwater        1884      11
# 17      Groundwater        1885      19
# 18      Groundwater        1886      16
# 19      Groundwater        1887      10
#
# Summary by water type × decade:
#    water_type_clean  decade  n_rows
# 0       Groundwater    1850       1
# 1       Groundwater    1860       5
# 2       Groundwater    1870      53
# 3       Groundwater    1880     174
# 4       Groundwater    1890     244
# 5       Groundwater    1900     548
# 6       Groundwater    1910     853
# 7       Groundwater    1920     562
# 8       Groundwater    1930     815
# 9       Groundwater    1940    1151
# 10      Groundwater    1950    1490
# 11      Groundwater    1960    1228
# 12      Groundwater    1970     721
# 13      Groundwater    1980       2
# 14       Irrigation    1820       1
# 15       Irrigation    1850       1
# 16       Irrigation    1860       1
# 17       Irrigation    1870      14
# 18       Irrigation    1880      25
# 19       Irrigation    1890      72

# %%
# %% Export plots as PNG
PLOT1_PATH = os.path.join(DATA_DIR, "counts_by_water_type.png")
PLOT2_PATH = os.path.join(DATA_DIR, "counts_by_water_type_decade.png")

# 1. Bar chart by water type
plt.figure(figsize=(8,5))
sns.barplot(data=summary_by_type, x='n_rows', y='water_type_clean')
plt.title("Counts by Water Type")
plt.xlabel("Number of Records")
plt.ylabel("Water Type")
plt.tight_layout()
plt.savefig(PLOT1_PATH, dpi=300)
plt.close()
print(f"Saved plot → {PLOT1_PATH}")

# 2. Stacked bar chart by decade
pivot_decade = summary_by_decade.pivot(index='decade', columns='water_type_clean', values='n_rows').fillna(0)
ax = pivot_decade.plot(kind='bar', stacked=True, figsize=(10,6), colormap='tab20c')
plt.title("Counts by Water Type × Decade")
plt.xlabel("Decade")
plt.ylabel("Number of Records")
plt.legend(title="Water Type", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.savefig(PLOT2_PATH, dpi=300)
plt.close()
print(f"Saved plot → {PLOT2_PATH}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 6
#       3 PLOT2_PATH = os.path.join(DATA_DIR, "counts_by_water_type_decade.png")
#       5 # 1. Bar chart by water type
# ----> 6 plt.figure(figsize=(8,5))
#       7 sns.barplot(data=summary_by_type, x='n_rows', y='water_type_clean')
#       8 plt.title("Counts by Water Type")
#
# NameError: name 'plt' is not defined
