# %%
import json
import pandas as pd
import re

# %%
cleaned_json = """[
    {
        "Watersource_Name": "Spring Pinches Sulphur",
        "County": "MENDOCINO",
        "Location": "21N/15W -1R,M 39°41'45\"N,123°28'46\"",
        "Townships_Ranges_Sections": [
            "21N",
            "15W",
            "-1R"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 39.695833,
        "Actual_Longitude": -123.479444,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "09/29/1966-09/29/1966",
        "Water_Type": "Springs",
        "KeyTerms": [
            "bicarbonate",
            "sodium",
            "carbonated"
        ]
    },
    {
        "Watersource_Name": "Mud Springs Valley Mud (Jackson Springs)",
        "County": "MENDOCINO",
        "Location": "21N/15W -19M,M 39°39'25\"N,123°35'15\"",
        "Townships_Ranges_Sections": [
            "21N",
            "15W",
            "-19M"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 39.656944,
        "Actual_Longitude": -123.5875,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "09/29/1966-09/29/1966",
        "Water_Type": "Springs",
        "KeyTerms": [
            "bicarbonate",
            "magnesium",
            "carbonated"
        ]
    },
    {
        "Watersource_Name": "Division California Highways",
        "County": "MENDOCINO",
        "Location": "23N/15W -19L,M 39*49'34\"N,123°34'48\"",
        "Townships_Ranges_Sections": [
            "23N",
            "15W",
            "-19L"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 39.826111,
        "Actual_Longitude": -123.58,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "09/28/1966",
        "Water_Type": "Springs",
        "KeyTerms": [
            "bicarbonate",
            "magnesium"
        ]
    },
    {
        "Watersource_Name": "Spring Stearns Congress F. A.",
        "County": "NAPA",
        "Location": "5N/4W -17C,M 38°17'04\"N,122°19'413\"",
        "Townships_Ranges_Sections": [
            "5N",
            "4W",
            "-17C"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 38.284444,
        "Actual_Longitude": -122.328056,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "06/1965-05/11/1965",
        "Water_Type": "Springs",
        "KeyTerms": [
            "bicarbonate",
            "calcium",
            "sodium"
        ]
    },
    {
        "Watersource_Name": "Imboden Pete",
        "County": "NAPA",
        "Location": "6N/3W -19X,M 38*20'50\"N,122\"14'06\"",
        "Townships_Ranges_Sections": [
            "6N",
            "3W",
            "-19X"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 38.347222,
        "Actual_Longitude": -122.235,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "05/11/1965-06/1965",
        "Water_Type": "Springs",
        "KeyTerms": [
            "bicarbonate",
            "magnesium"
        ]
    },
    {
        "Watersource_Name": "Soda Springs Nape Soda Jacksons Springs Nasser",
        "County": "NAPA",
        "Location": "6N/4W -2N,M 38*23'23\"N,122°16'39\"",
        "Townships_Ranges_Sections": [
            "6N",
            "4W",
            "-2N"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 38.389722,
        "Actual_Longitude": -122.2775,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "06/1965-05/",
        "Water_Type": "Springs",
        "KeyTerms": [
            "bicarbonate",
            "calcium",
            "sodium"
        ]
    },
    {
        "Watersource_Name": "Springs Vichy Lepori Harris",
        "County": "NAPA",
        "Location": "6N/4W -25E,M 38*20'20\"N,122\"15'33\"",
        "Townships_Ranges_Sections": [
            "6N",
            "4W",
            "-25E"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 38.338889,
        "Actual_Longitude": -122.259167,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "06/1965-05/",
        "Water_Type": "Springs",
        "KeyTerms": [
            "bicarbonate",
            "calcium"
        ]
    },
    {
        "Watersource_Name": "State Home California Veterans",
        "County": "NAPA",
        "Location": "6N/5W -1L,M 38°23'49\"N,122*22'00\"",
        "Townships_Ranges_Sections": [
            "6N",
            "5W",
            "-1L"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 38.396944,
        "Actual_Longitude": -122.366667,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "06/1965-05/",
        "Water_Type": "Springs",
        "KeyTerms": [
            "bicarbonate",
            "calcium"
        ]
    },
    {
        "Watersource_Name": "Division California of Highways",
        "County": "NAPA",
        "Location": "TN/3W -6E,M 38*29'04\"N,122\"14'29\"",
        "Townships_Ranges_Sections": [
            "7N",
            "3W",
            "-6E"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 38.484444,
        "Actual_Longitude": -122.241389,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "07/1965-05/",
        "Water_Type": "Springs",
        "KeyTerms": []
    },
    {
        "Watersource_Name": "Springs Springs Inc. Camps, Sulphur White California-Nevada",
        "County": "NAPA",
        "Location": "TN/GW -2D,M 38°29'26\"N,122°29'42\"",
        "Townships_Ranges_Sections": [
            "7N",
            "3W",
            "-2D"
        ],
        "Temporal_Resolution": null,
        "Units_Of_Measurement": {
            "Temperature": "F",
            "Discharge": "gpm"
        },
        "Actual_Latitude": 38.490556,
        "Actual_Longitude": -122.495,
        "Inferred_Latitude": null,
        "Inferred_Longitude": null,
        "Dates_of_Recording": "05/11/1965",
        "Water_Type": "Springs",
        "KeyTerms": [
            "bicarbonate",
            "sodium"
        ]
    }
]
"""

# %%
df = pd.read_csv('/Users/yiboliang/Desktop/LLM STUFF/[June 24] Metadata extraction Run 4/run4_v1.csv')

# %%
df.head()
# Out:
#    Unnamed: 0     ID  PAGE_NUMBER  Inferred_Latitude  Inferred_Longitude  \
# 0           0  56394          282                NaN                 NaN
# 1           1   2846           29             33.966            -116.119
# 2           2   2846           29             33.800            -116.600
# 3           3   2846           29             33.966            -116.119
# 4           4    366           10                NaN                 NaN
#
#    Actual_Latitude  Actual_Longitude                            Location  \
# 0        37.666389       -120.441111                  Near La Grange, CA
# 1              NaN               NaN  Upper Coachella Valley, California
# 2              NaN               NaN  Upper Coachella Valley, California
# 3              NaN               NaN  Upper Coachella Valley, California
# 4              NaN               NaN                                 NaN
#
#         Townships_Ranges_Sections  \
# 0  ['NW14 sec.2 T.3 S., R.14 E.']
# ...

# %%
cleaned_json
# Out:
# '[\n    {\n        "Watersource_Name": "Mount Diablo Baseline and Meridian",\n        "County": "San Joaquin County, California",\n        "Townships_Ranges_Sections": [\n            "T. 30 S., R. 27 E.",\n            "T. 30 S., R. 28 E.",\n            "T. 30 S., R. 29 E.",\n            "T. 30 S., R. 30 E.",\n            "T. 31 S., R. 24 E.",\n            "T. 31 S., R. 25 E.",\n            "T. 31 S., R. 26 E.",\n            "T. 31 S., R. 27 E.",\n            "T. 31 S., R. 28 E.",\n            "T. 31 S., R. 29 E.",\n            "T. 31 S., R. 30 E.",\n            "T. 32 S., R. 23 E.",\n            "T. 32 S., R. 24 E.",\n            "T. 32 S., R. 25 E.",\n            "T. 32 S., R. 26 E.",\n            "T. 32 S., R. 27 E.",\n            "T. 32 S., R. 28 E.",\n            "T. 32 S., R. 29 E.",\n            "T. 32 S., R. 30 E."\n        ],\n        "Temporal_Resolution": "Annual",\n        "Units_Of_Measurement": "Acre-feet",\n        "Latitude": null,\n        "Longitude": null,\n        
# ...

# %%
dicts = json.loads(cleaned_json)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 dicts = json.loads(cleaned_json)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
# ...

# %%
try:
    dicts = json.loads(cleaned_json) 
    if isinstance(dicts, list):
        for dic in dicts:
            dic.update({"ID": 10372, "PAGE_NUMBER": 13})
            df = pd.concat([df, pd.DataFrame(dicts)], ignore_index=True)
        else:
            dic.update({"ID": 10372, "PAGE_NUMBER": 13})
            df = pd.concat([df, pd.DataFrame([dicts])], ignore_index=True)
        
except Exception as e:
    try:
        cleaned_json = ''.join(cleaned_json.rsplit(',', 1)[0]) + "]"
        dicts = json.loads(cleaned_json) 
        if isinstance(dicts, list):
            for dic in dicts:
                dic.update({"ID": 10372, "PAGE_NUMBER": 13})
                df = pd.concat([df, pd.DataFrame(dicts)], ignore_index=True)
        else:
            dic.update({"ID": 10372, "PAGE_NUMBER": 13})
            df = pd.concat([df, pd.DataFrame([dicts])], ignore_index=True)
    except Exception as f:
        print(f)

df.to_csv('/Users/yiboliang/Desktop/LLM STUFF/[June 24] Metadata extraction Run 4/run4_v1.csv')
# Out:
# Expecting ',' delimiter: line 15 column 33 (char 705)
